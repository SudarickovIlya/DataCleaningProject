# %%
import pandas as pd
pd.__version__
# Out:
# '1.5.3'

# %%
countries_df = pd.DataFrame({
    'country': ['Англия', 'Канада', 'США', 'Россия', 'Украина', 'Беларусь', 'Казахстан'],
    'population': [56.29, 38.05, 322.28, 146.24, 45.5, 9.5, 17.04],
    'square': [133396, 9984670, 9826630, 17125191, 603628, 207600, 2724902]
})

countries_df.to_csv('data/countries.csv', index = True, sep = ';', decimal = ',', columns = ['country', 'population', 'square'])

# %%
countries_data = pd.read_csv('data/countries.csv', sep=';', decimal=',', names=['country', 'population', 'square'], skiprows=1)
countries_data
# Out:
#      country  population    square
# 0     Англия       56.29    133396
# 1     Канада       38.05   9984670
# 2        США      322.28   9826630
# 3     Россия      146.24  17125191
# 4    Украина       45.50    603628
# 5   Беларусь        9.50    207600
# 6  Казахстан       17.04   2724902

# %%
data = pd.read_csv('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv', sep=',', skiprows=1)
data
# Out:
#            1    Abbotsford      85 Turner St  2  h  1480000.0   S      Biggin  \
# 0          2    Abbotsford   25 Bloomburg St  2  h  1035000.0   S      Biggin
# 1          4    Abbotsford      5 Charles St  3  h  1465000.0  SP      Biggin
# 2          5    Abbotsford  40 Federation La  3  h   850000.0  PI      Biggin
# 3          6    Abbotsford       55a Park St  4  h  1600000.0  VB      Nelson
# 4         10    Abbotsford    129 Charles St  2  h   941000.0   S      Jellis
# ...      ...           ...               ... .. ..        ...  ..         ...
# 18390  23540  Williamstown   8/2 Thompson St  2  t   622500.0  SP        Greg
# 18391  23541  Williamstown      96 Verdon St  4  h  2500000.0  PI     Sweeney
# 18392  23544     Yallambie      17 Amaroo Wy  4  h  1100000.0   S  Buckingham
# 18393  23545    Yarraville        6 Agnes St  4  h  1285000.0  SP     Village
# 18394  23546    Yarraville     33 Freeman St  4  h  1050000.0  VB     Village
#
# ...
